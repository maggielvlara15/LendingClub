# %% [markdown]
# # Lending Club Dataset Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from create_table import *

# %%
df = data_processing('loan.csv')

# %% [markdown]
# #### We will start with exploring the basic information about the dataset, to do so, I will try to solve the following questions:
#      1. What is the distribution of loan amounts?
#      2. What is the distribution of interest rate?
#      3. What is the total loan amounts for each year?
#      4. What is the number of issued loans for each year?
#
# #### As follow up questions, we may also want to know:
#      What amout was mostly issued to the borrowers?
#      What interest rate was mostly issued to the borrowers?
#      Which year had the most loan amount and which year had the least?
#      Which year issued the biggest numbers of loans and which year issued the smallest?

# %%
df['int_round'] = df['int_rate'].round(0).astype(int)

#looking at the loan_amnt column
plt.figure(figsize=(14,10))

# Loan Amt plot
plt.subplot(211)
g = sns.distplot(df["loan_amnt"])
g.set_xlabel("Loan Amount", fontsize=)15
g.set_ylabel("Frequency", fontsize=1)
g.set_title("Loan Amount Distribuition", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Loan Amount Distribuition')
